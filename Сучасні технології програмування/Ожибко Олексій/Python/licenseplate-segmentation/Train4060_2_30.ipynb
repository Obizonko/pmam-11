# %%
# !python train_model.py --epochs 20 --output-dir ./output --dataset-dir ./dataset
# Out:
# Namespace(batch_size=2, dataset_dir='./dataset', device='cuda', epochs=20, freeze_backbone=False, lr=0.001, momentum=0.9, output_dir='./output', print_freq=10, resume='', swa_freq=5, swa_start=10, test_only=False, use_swa=False, weight_decay=0.0001, workers=4)
# sigmoid shape: torch.Size([2, 1, 480, 480])
# sigmoid_aux shape: torch.Size([2, 1, 480, 480])
# target shape: torch.Size([2, 1, 480, 480])
# Epoch: [0]  [  0/100]  eta: 0:20:56  lr: 0.000999549988747937  loss: 0.9063 (0.9063)  iou: 14.4721 (14.4721)  time: 12.5621  data: 8.2504  max mem: 3700
# sigmoid shape: torch.Size([2, 1, 480, 480])
# sigmoid_aux shape: torch.Size([2, 1, 480, 480])
# target shape: torch.Size([2, 1, 480, 480])
# sigmoid shape: torch.Size([2, 1, 480, 480])
# sigmoid_aux shape: torch.Size([2, 1, 480, 480])
# target shape: torch.Size([2, 1, 480, 480])
# sigmoid shape: torch.Size([2, 1, 480, 480])
# sigmoid_aux shape: torch.Size([2, 1, 480, 480])
# target shape: torch.Size([2, 1, 480, 480])
# ...
